# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size = (4,4)

sample = np.random.exponential(1, size)
print(sample)
# Out:
# [[0.60928988 1.11095188 0.21603639 1.04630212]
#  [0.31576056 0.81888281 1.25558453 0.5404024 ]
#  [0.35139682 0.97645498 2.75575166 0.96019706]
#  [0.82324754 0.62874375 1.82109217 0.72497106]]

# %%
size = (100000,1)

sample2 = np.random.exponential(1, size)
print(sample2)
# Out:
# [[0.80579611]
#  [0.20864588]
#  [0.55475603]
#  ...
#  [1.38644719]
#  [1.84333548]
#  [0.25839643]]

# %%
plt.hist(sample2, bins=25, density=True, alpha=0.6, color='g')
# Out:
# (array([8.24909665e-01, 5.36227686e-01, 3.54475745e-01, 2.39609683e-01,
#         1.57507023e-01, 1.05692309e-01, 6.99923352e-02, 4.64269546e-02,
#         3.18654425e-02, 2.04831938e-02, 1.37848982e-02, 8.49421543e-03,
#         5.43629788e-03, 3.90733910e-03, 2.98511000e-03, 1.94153496e-03,
#         1.18919016e-03, 6.55268048e-04, 5.33922113e-04, 3.88306991e-04,
#         1.94153496e-04, 7.28075609e-05, 2.42691870e-05, 4.85383739e-05,
#         7.28075609e-05]),
#  array([2.61835672e-07, 4.12045380e-01, 8.24090498e-01, 1.23613562e+00,
#         1.64818073e+00, 2.06022585e+00, 2.47227097e+00, 2.88431609e+00,
#         3.29636120e+00, 3.70840632e+00, 4.12045144e+00, 4.53249656e+00,
#         4.94454168e+00, 5.35658679e+00, 5.76863191e+00, 6.18067703e+00,
#         6.59272215e+00, 7.00476727e+00, 7.41681238e+00, 7.82885750e+00,
#         8.24090262e+00, 8.65294774e+00, 9.06499285e+00, 9.47703797e+00,
#         9.88908309e+00, 1.03011282e+01]),
#  <BarContainer object of 25 artists>)

# %%
plt.hist(np.random.rand(100000), density=True, bins=100, histtype="step", color="blue", label="rand")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()
fig = plt.figure()

# %%
ax = plt.axes(projection='3d')
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-5, 5, 30)
y = np.linspace(-5, 5, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
